# %% [markdown]
# <a align="center" href="https://ultralytics.com/hub" target="_blank">
# <img width="1024", src="https://github.com/ultralytics/assets/raw/main/im/ultralytics-hub.png"></a>
#
# <div align="center">
#
# [中文](https://docs.ultralytics.com/zh/hub/) | [한국어](https://docs.ultralytics.com/ko/hub/) | [日本語](https://docs.ultralytics.com/ja/hub/) | [Русский](https://docs.ultralytics.com/ru/hub/) | [Deutsch](https://docs.ultralytics.com/de/hub/) | [Français](https://docs.ultralytics.com/fr/hub/) | [Español](https://docs.ultralytics.com/es/hub/) | [Português](https://docs.ultralytics.com/pt/hub/) | [Türkçe](https://docs.ultralytics.com/tr/hub/) | [Tiếng Việt](https://docs.ultralytics.com/vi/hub/) | [العربية](https://docs.ultralytics.com/ar/hub/)
#
#   <a href="https://github.com/ultralytics/hub/actions/workflows/ci.yaml"><img src="https://github.com/ultralytics/hub/actions/workflows/ci.yaml/badge.svg" alt="CI CPU"></a>
#   <a href="https://colab.research.google.com/github/ultralytics/hub/blob/main/hub.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#
#   <a href="https://ultralytics.com/discord"><img alt="Discord" src="https://img.shields.io/discord/1089800235347353640?logo=discord&logoColor=white&label=Discord&color=blue"></a>
#   <a href="https://community.ultralytics.com"><img alt="Ultralytics Forums" src="https://img.shields.io/discourse/users?server=https%3A%2F%2Fcommunity.ultralytics.com&logo=discourse&label=Forums&color=blue"></a>
#   <a href="https://reddit.com/r/ultralytics"><img alt="Ultralytics Reddit" src="https://img.shields.io/reddit/subreddit-subscribers/ultralytics?style=flat&logo=reddit&logoColor=white&label=Reddit&color=blue"></a>
#
# Welcome to the [Ultralytics](https://ultralytics.com/) HUB notebook!
#
# This notebook allows you to train Ultralytics [YOLO](https://github.com/ultralytics/ultralytics) 🚀 models using [HUB](https://hub.ultralytics.com/). Please browse the HUB <a href="https://docs.ultralytics.com/hub/">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/hub/issues/new/choose">GitHub</a> for support, and join our <a href="https://ultralytics.com/discord">Discord</a> community for questions and discussions!
# </div>

# %% [markdown]
# # Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://www.pepy.tech/projects/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **yolov5n trainig till 30 epochs**

# %%
# %pip install ultralytics  # install
from ultralytics import YOLO, checks, hub

checks()  # checks
# Out:
# Ultralytics 8.3.36 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.5/112.6 GB disk)

# %% [markdown]
# # Start
#
# ⚡ Login with your API key, load your YOLO 🚀 model, and start training in 3 lines of code!

# %%
hub.login('29e41fe9eea55e4fce335a4052fb982c9051d5f687')

model = YOLO('https://hub.ultralytics.com/models/AnqWA7psj5NRmETal2nq')
results = model.train()
# Out:
# requirements: Ultralytics requirement ['hub-sdk>=0.0.12'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 6.1 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 2.9s, installed 1 package: ['hub-sdk>=0.0.12']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Ultralytics HUB: New authentication successful ✅
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/AnqWA7psj5NRmETal2nq 🚀
# ...
# 100%|██████████| 5.31M/5.31M [00:00<00:00, 59.6MB/s]
# Ultralytics 8.3.36 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # **Accuracy chart for yolov5n**

# %%
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Load the trained YOLO model from the given path
model = YOLO('/content/last.pt')

# Evaluate the model on the validation dataset
results = model.val()

# Plot mAP (mean Average Precision) over the validation data
plt.figure(figsize=(10, 5))
plt.plot(results.maps, label='mAP')
plt.title("mAP Over Validation")
plt.xlabel("Epochs / Validation Set")
plt.ylabel("mAP (Mean Average Precision)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Ultralytics 8.3.36 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv5n summary (fused): 193 layers, 2,504,894 parameters, 0 gradients, 7.1 GFLOPs
# val: Scanning /content/datasets/VisDrone/VisDrone2019-DET-val/labels.cache... 548 images, 0 backgrounds, 0 corrupt: 100%|██████████| 548/548 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 35/35 [00:25<00:00,  1.35it/s]
#                    all        548      38759      0.385      0.297      0.282       0.16
#             pedestrian        520       8844      0.374       0.31      0.293      0.121
#                 people        482       5125      0.481      0.192      0.238      0.081
#                bicycle        364       1287      0.162     0.0668     0.0506     0.0196
#                    car        515      14064      0.566      0.712      0.707      0.472
# ...

# %%
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Define the model path for YOLOv5n
model_path = '/content/last.pt'  # Path for YOLOv5n

# List to store mAP values
mAP_values = []

# Evaluate YOLOv5n and get the mAP value
model = YOLO(model_path)
results = model.val()  # Perform validation

# Access mAP@0.5 directly using maps attribute
mAP_values.append(results.maps[0])  # results.maps is a list containing mAP values for different IoU thresholds.
                                    # results.maps[0] corresponds to mAP@0.5

# Plotting the result for YOLOv5n
plt.figure(figsize=(8, 6))
plt.bar(['YOLOv5n'], mAP_values, color=['green'])
plt.title("Accuracy: YOLOv5n")
plt.xlabel("Model")
plt.ylabel("Accuracy (mAP@0.5)")
plt.grid(True)
plt.show()
# Out:
# Ultralytics 8.3.36 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv5n summary (fused): 193 layers, 2,504,894 parameters, 0 gradients, 7.1 GFLOPs
# val: Scanning /content/datasets/VisDrone/VisDrone2019-DET-val/labels.cache... 548 images, 0 backgrounds, 0 corrupt: 100%|██████████| 548/548 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 35/35 [00:23<00:00,  1.46it/s]
#                    all        548      38759      0.385      0.297      0.282       0.16
#             pedestrian        520       8844      0.374       0.31      0.293      0.121
#                 people        482       5125      0.481      0.192      0.238      0.081
#                bicycle        364       1287      0.162     0.0668     0.0506     0.0196
#                    car        515      14064      0.566      0.712      0.707      0.472
# ...

# %% [markdown]
# # **Comparison of Models accuracy**

# %% [markdown]
# **v8 and v5n comaprison (but idk its wrong?)**

# %%
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Define the model paths
model_paths = [
    '/content/mynewmodel.pt',  # yolov8s
    '/content/last.pt'         # yolov5n
]

# Names of the models for the plot
model_names = ['YOLOv8s', 'YOLOv5n']

# List to store mAP values for each model
mAP_values = []

# Evaluate each model and get the mAP value
for model_path in model_paths:
    model = YOLO(model_path)

    # Specify the 'data' argument in the val() function to match your validation dataset yaml file
    # Replace 'path/to/your/val_data.yaml' with the actual path to your validation data yaml file.
    results = model.val(data='/content/VisDrone.yaml')  # Perform validation with specified data

    # Access mAP@0.5 using results.maps[0] instead of results.metrics['mAP_0.5']
    mAP_values.append(results.maps[0])  # Extract mAP value at 0.5 threshold

# Plotting the results
plt.figure(figsize=(8, 6))
plt.bar(model_names, mAP_values, color=['blue', 'green'])
plt.title("Accuracy Comparison: YOLOv8s vs YOLOv5n")
plt.xlabel("Model")
plt.ylabel("Accuracy (mAP@0.5)")
plt.grid(True)
plt.show()
# Out:
# Ultralytics 8.3.36 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/datasets/VisDrone/VisDrone2019-DET-val/labels.cache... 548 images, 0 backgrounds, 0 corrupt: 100%|██████████| 548/548 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 35/35 [00:22<00:00,  1.55it/s]
#                    all        548      38759       0.45      0.349      0.347      0.201
#             pedestrian        520       8844      0.458      0.375      0.377      0.165
#                 people        482       5125      0.497      0.226      0.266     0.0885
#                bicycle        364       1287      0.212      0.134     0.0796     0.0307
#                    car        515      14064      0.665      0.759      0.771      0.526
#                    van        421       1975       0.47      0.426      0.417      0.287
# ...

# %% [markdown]
# **Comaprison v8 and v5n**

# %%
# Step 1: Import necessary libraries
from ultralytics import YOLO
import matplotlib.pyplot as plt
import os

# Step 2: Load the Models
model_v8 = YOLO('/content/mynewmodel.pt')  # YOLOv8s (Small)
model_v5n = YOLO('/content/last.pt')       # YOLOv5n

# Step 3: Evaluate Accuracy
results_v8 = model_v8.val(data='/content/VisDrone.yaml')
results_v5n = model_v5n.val(data='/content/VisDrone.yaml')

# Extract accuracy metrics (e.g., mAP@0.5)
accuracy_v8 = results_v8.box.map50  # Mean Average Precision at IoU=0.5 for YOLOv8
accuracy_v5n = results_v5n.box.map50  # Mean Average Precision at IoU=0.5 for YOLOv5n

# Step 4: Visualize the Results and Save the Graph
labels = ['YOLOv8', 'YOLOv5n']
accuracy = [accuracy_v8, accuracy_v5n]

plt.bar(labels, accuracy, color=['blue', 'cyan'])
plt.xlabel('Model')
plt.ylabel('Accuracy (mAP@0.5)')
plt.title('Accuracy Comparison: YOLOv8 vs YOLOv5n')

# Save the graph as an image
graph_path = '/content/comparison_v8_v5n_graph.png'
plt.savefig(graph_path)

# Show the graph in the notebook
plt.show()

# Step 5: Summarize in Text and Save to a File
comparison_text = f"YOLOv8 Model Accuracy (mAP@0.5): {accuracy_v8:.4f}\n"
comparison_text += f"YOLOv5n Model Accuracy (mAP@0.5): {accuracy_v5n:.4f}\n"

if accuracy_v8 > accuracy_v5n:
    comparison_text += "YOLOv8 performs better than YOLOv5n.\n"
else:
    comparison_text += "YOLOv5n performs better than YOLOv8.\n"

# Save the comparison text and graph path into a file
comparison_file_path = '/content/comparison_v8_v5n.txt'
with open(comparison_file_path, 'w') as file:
    file.write(comparison_text)
    file.write(f"Graph saved as: {graph_path}\n")

# Display the paths where the files are saved
print(f"Comparison results saved to: {comparison_file_path}")
print(f"Graph saved to: {graph_path}")
# Out:
# Ultralytics 8.3.36 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/datasets/VisDrone/VisDrone2019-DET-val/labels.cache... 548 images, 0 backgrounds, 0 corrupt: 100%|██████████| 548/548 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 35/35 [00:24<00:00,  1.44it/s]
#                    all        548      38759       0.45      0.349      0.347      0.201
#             pedestrian        520       8844      0.458      0.375      0.377      0.165
#                 people        482       5125      0.497      0.226      0.266     0.0885
#                bicycle        364       1287      0.212      0.134     0.0796     0.0307
#                    car        515      14064      0.665      0.759      0.771      0.526
#                    van        421       1975       0.47      0.426      0.417      0.287
# ...

# %% [markdown]
# **Comparison v8 v5n v9s v11x**

# %%
# Step 1: Import necessary libraries
from ultralytics import YOLO
import matplotlib.pyplot as plt
import os

# Step 2: Load the Models
model_v8 = YOLO('/content/mynewmodel.pt')           # YOLOv8s (Small)
model_v5n = YOLO('/content/last.pt')       # YOLOv5n
model_v9 = YOLO('/content/mynewmodelv9.pt')         # YOLOv9s (small)
model_v11x = YOLO('https://hub.ultralytics.com/models/CwpL4ff6AUcqFgoVDwXZ')  # YOLOv11x

# Step 3: Evaluate Accuracy
results_v8 = model_v8.val(data='/content/VisDrone.yaml')
results_v5n = model_v5n.val(data='/content/VisDrone.yaml')
results_v9 = model_v9.val(data='/content/VisDrone.yaml')
results_v11x = model_v11x.val(data='/content/VisDrone.yaml')

# Extract accuracy metrics (e.g., mAP@0.5)
accuracy_v8 = results_v8.box.map50  # Mean Average Precision at IoU=0.5 for YOLOv8
accuracy_v5n = results_v5n.box.map50  # Mean Average Precision at IoU=0.5 for YOLOv5n
accuracy_v9 = results_v9.box.map50  # Mean Average Precision at IoU=0.5 for YOLOv9
accuracy_v11x = results_v11x.box.map50  # Mean Average Precision at IoU=0.5 for YOLOv11x

# Step 4: Visualize the Results and Save the Graph
labels = ['YOLOv8', 'YOLOv5n', 'YOLOv9', 'YOLOv11x']
accuracy = [accuracy_v8, accuracy_v5n, accuracy_v9, accuracy_v11x]

plt.bar(labels, accuracy, color=['blue', 'cyan', 'orange', 'green'])
plt.xlabel('Model')
plt.ylabel('Accuracy (mAP@0.5)')
plt.title('Accuracy Comparison: YOLOv8 vs YOLOv5n vs YOLOv9 vs YOLOv11x')

# Save the graph as an image
graph_path = '/content/comparison_v8_v5n_v9_v11x_graph.png'
plt.savefig(graph_path)

# Show the graph in the notebook
plt.show()

# Step 5: Summarize in Text and Save to a File
comparison_text = f"YOLOv8 Model Accuracy (mAP@0.5): {accuracy_v8:.4f}\n"
comparison_text += f"YOLOv5n Model Accuracy (mAP@0.5): {accuracy_v5n:.4f}\n"
comparison_text += f"YOLOv9 Model Accuracy (mAP@0.5): {accuracy_v9:.4f}\n"
comparison_text += f"YOLOv11x Model Accuracy (mAP@0.5): {accuracy_v11x:.4f}\n"

if accuracy_v8 > accuracy_v5n and accuracy_v8 > accuracy_v9 and accuracy_v8 > accuracy_v11x:
    comparison_text += "YOLOv8 performs better than YOLOv5n, YOLOv9, and YOLOv11x.\n"
elif accuracy_v5n > accuracy_v8 and accuracy_v5n > accuracy_v9 and accuracy_v5n > accuracy_v11x:
    comparison_text += "YOLOv5n performs better than YOLOv8, YOLOv9, and YOLOv11x.\n"
elif accuracy_v9 > accuracy_v8 and accuracy_v9 > accuracy_v5n and accuracy_v9 > accuracy_v11x:
    comparison_text += "YOLOv9 performs better than YOLOv8, YOLOv5n, and YOLOv11x.\n"
else:
    comparison_text += "YOLOv11x performs better than YOLOv8, YOLOv5n, and YOLOv9.\n"

# Save the comparison text and graph path into a file
comparison_file_path = '/content/comparison_v8_v5n_v9_v11x.txt'
with open(comparison_file_path, 'w') as file:
    file.write(comparison_text)
    file.write(f"Graph saved as: {graph_path}\n")

# Display the paths where the files are saved
print(f"Comparison results saved to: {comparison_file_path}")
print(f"Graph saved to: {graph_path}")
# Out:
# Loading trained HUB model https://hub.ultralytics.com/models/CwpL4ff6AUcqFgoVDwXZ 🚀
# Found https://storage.googleapis.com/ultralytics-hub.appspot.com/users/md0ltA6tizggxcCfamzy94Y2CVh2/models/CwpL4ff6AUcqFgoVDwXZ/best.pt locally at weights/hub/CwpL4ff6AUcqFgoVDwXZ/best.pt
# Ultralytics 8.3.36 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/datasets/VisDrone/VisDrone2019-DET-val/labels.cache... 548 images, 0 backgrounds, 0 corrupt: 100%|██████████| 548/548 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 35/35 [00:26<00:00,  1.34it/s]
#                    all        548      38759       0.45      0.349      0.347      0.201
#             pedestrian        520       8844      0.458      0.375      0.377      0.165
#                 people        482       5125      0.497      0.226      0.266     0.0885
# ...

# %% [markdown]
# # **TensoRt for video1 and 2 for yolov5n**

# %%
import torch
import cv2
import random
import time
import pathlib
from ultralytics import YOLO
from ultralytics.utils import LOGGER
from ultralytics.nn.autobackend import AutoBackend
import matplotlib.pyplot as plt

# Define the TensorRT detection function
def tensorrt_detection(model, source, image):
    im = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Preprocess the input image (example)
    preds = model(im)  # Perform inference
    results = preds[0]  # Assuming the output is the same as YOLO
    d = results.boxes  # Extract detected boxes

    # Handle multiple or single detections
    tensor_size = d.cls.size()[0]
    if tensor_size > 1:
        cls, conf, box = d.cls.squeeze(), d.conf.squeeze(), d.xyxy.squeeze()
    else:
        cls, conf, box = d.cls, d.conf, d.xyxy

    return cls, conf, box

# Define YOLOv8 detection function
def yolov8_detection(model, image):
    results = model.predict(image, imgsz=640, conf=0.5, verbose=False)  # Predict with YOLOv8
    result = results[0].cpu()  # Move results to CPU
    box = result.boxes.xyxy.numpy()  # Extract bounding boxes
    conf = result.boxes.conf.numpy()  # Extract confidence scores
    cls = result.boxes.cls.numpy().astype(int)  # Extract class IDs as integers

    return cls, conf, box

# Function to draw boxes on the image
def draw_box(image, detection_output, label_map, colors):
    for cls, conf, box in detection_output:
        color = colors[cls]
        x1, y1, x2, y2 = map(int, box)
        label = f"{label_map[cls]} {conf:.2f}"
        cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)
        cv2.putText(image, label, (x1, y1-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
    return image

# Function to draw FPS on the image
def draw_fps(fps, image):
    cv2.putText(image, f"FPS: {fps:.2f}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
    return image

# Function to generate output video name
def get_name(source):
    return pathlib.Path(source).stem

# Function to generate output save path
def get_save_path(file_name, name):
    return f"{name}/{file_name}_output_yolov5n.mp4"

# Define the main detection function
def detection(model_path, source, name, max_frames=500):
    # Check if the model is a TensorRT engine or YOLO model
    file_extension = pathlib.Path(model_path).suffix

    if file_extension == ".engine":
        model = AutoBackend(model_path, device=torch.device('cuda:0'), fp16=True)
        model.warmup()  # Warmup TensorRT model
    else:
        model = YOLO(model_path)  # Load YOLO model

    # Get class names and generate random colors for each class
    label_map = model.names
    COLORS = [[random.randint(0, 255) for _ in range(3)] for _ in label_map]

    # Set up video capture
    video_cap = cv2.VideoCapture(source)
    total_frames = min(int(video_cap.get(cv2.CAP_PROP_FRAME_COUNT)), max_frames)  # Limit to max_frames
    frame_width = int(video_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(video_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Prepare for frame-by-frame processing
    frame_count = 0
    total_fps = 0
    video_frames = []
    fps_values = []
    detection_counts = []

    # Loop through each frame in the video
    while video_cap.isOpened() and frame_count < max_frames:
        ret, frame = video_cap.read()
        if not ret:
            break

        start = time.time()  # Start timing

        # Perform detection based on model type
        if file_extension == ".engine":
            cls, conf, box = tensorrt_detection(model, source, frame)
        else:
            cls, conf, box = yolov8_detection(model, frame)

        # Pack detections and annotate the frame
        detection_output = list(zip(cls, conf, box))
        image_output = draw_box(frame, detection_output, label_map, COLORS)

        end = time.time()  # End timing
        fps = 1 / (end - start)  # Calculate FPS
        frame_count += 1
        total_fps += fps

        # Annotate FPS on the frame
        image_output = draw_fps(total_fps / frame_count, image_output)
        video_frames.append(image_output)  # Save annotated frame

        # Collect FPS and detection counts for graphing
        fps_values.append(fps)
        detection_counts.append(len(cls))

        print(f"Processed frame {frame_count}/{total_frames}")  # Log progress

    avg_fps = total_fps / frame_count  # Calculate average FPS
    print(f"Average FPS: {avg_fps}")

    # Save the annotated video
    file_name = get_name(source)
    save_path = get_save_path(file_name, name)
    out = cv2.VideoWriter(save_path, cv2.VideoWriter_fourcc(*'XVID'), int(avg_fps), (frame_width, frame_height))

    for frame in video_frames:
        out.write(frame)

    out.release()  # Release the writer
    print(f"Video saved at: {save_path}")

    # Plot FPS graph (Line Graph)
    plt.figure(figsize=(10, 5))
    plt.plot(fps_values, label='FPS', color='blue')
    plt.title("FPS Over Time")
    plt.xlabel("Frame Number")
    plt.ylabel("FPS")
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot number of detections graph (Line Graph)
    plt.figure(figsize=(10, 5))
    plt.plot(detection_counts, label='Detections', color='green')
    plt.title("Number of Detections Over Time")
    plt.xlabel("Frame Number")
    plt.ylabel("Number of Detections")
    plt.legend()
    plt.grid(True)
    plt.show()

# Paths for your model and video
model_path = '/content/last.pt'  # Path to your YOLO model
video_path = '/content/drive/MyDrive/video1.mp4'    # Path to your video
output_folder = "/content"  # Folder for saving output

# Run detection for first 500 frames
detection(model_path, video_path, output_folder, max_frames=500)
# Out:
# Processed frame 1/500
# Processed frame 2/500
# Processed frame 3/500
# Processed frame 4/500
# Processed frame 5/500
# Processed frame 6/500
# Processed frame 7/500
# Processed frame 8/500
# Processed frame 9/500
# Processed frame 10/500
# Processed frame 11/500
# Processed frame 12/500
# Processed frame 13/500
# Processed frame 14/500
# Processed frame 15/500
# Processed frame 16/500
# Processed frame 17/500
# Processed frame 18/500
# Processed frame 19/500
# Processed frame 20/500
# Processed frame 21/500
# Processed frame 22/500
# Processed frame 23/500
# Processed frame 24/500
# Processed frame 25/500
# Processed frame 26/500
# Processed frame 27/500
# Processed frame 28/500
# Processed frame 29/500
# Processed frame 30/500
# Processed frame 31/500
# Processed frame 32/500
# Processed frame 33/500
# Processed frame 34/500
# Processed frame 35/500
# Processed frame 36/500
# Processed frame 37/500
# Processed frame 38/500
# Processed frame 39/500
# Processed frame 40/500
# ...

# %%
import torch
import cv2
import random
import time
import pathlib
from ultralytics import YOLO
from ultralytics.utils import LOGGER
from ultralytics.nn.autobackend import AutoBackend
import matplotlib.pyplot as plt

# Define the TensorRT detection function
def tensorrt_detection(model, source, image):
    im = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Preprocess the input image (example)
    preds = model(im)  # Perform inference
    results = preds[0]  # Assuming the output is the same as YOLO
    d = results.boxes  # Extract detected boxes

    # Handle multiple or single detections
    tensor_size = d.cls.size()[0]
    if tensor_size > 1:
        cls, conf, box = d.cls.squeeze(), d.conf.squeeze(), d.xyxy.squeeze()
    else:
        cls, conf, box = d.cls, d.conf, d.xyxy

    return cls, conf, box

# Define YOLOv8 detection function
def yolov8_detection(model, image):
    results = model.predict(image, imgsz=640, conf=0.5, verbose=False)  # Predict with YOLOv8
    result = results[0].cpu()  # Move results to CPU
    box = result.boxes.xyxy.numpy()  # Extract bounding boxes
    conf = result.boxes.conf.numpy()  # Extract confidence scores
    cls = result.boxes.cls.numpy().astype(int)  # Extract class IDs as integers

    return cls, conf, box

# Function to draw boxes on the image
def draw_box(image, detection_output, label_map, colors):
    for cls, conf, box in detection_output:
        color = colors[cls]
        x1, y1, x2, y2 = map(int, box)
        label = f"{label_map[cls]} {conf:.2f}"
        cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)
        cv2.putText(image, label, (x1, y1-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
    return image

# Function to draw FPS on the image
def draw_fps(fps, image):
    cv2.putText(image, f"FPS: {fps:.2f}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
    return image

# Function to generate output video name
def get_name(source):
    return pathlib.Path(source).stem

# Function to generate output save path
def get_save_path(file_name, name):
    return f"{name}/{file_name}_output_yolov5nn.mp4"

# Define the main detection function
def detection(model_path, source, name, max_frames=500):
    # Check if the model is a TensorRT engine or YOLO model
    file_extension = pathlib.Path(model_path).suffix

    if file_extension == ".engine":
        model = AutoBackend(model_path, device=torch.device('cuda:0'), fp16=True)
        model.warmup()  # Warmup TensorRT model
    else:
        model = YOLO(model_path)  # Load YOLO model

    # Get class names and generate random colors for each class
    label_map = model.names
    COLORS = [[random.randint(0, 255) for _ in range(3)] for _ in label_map]

    # Set up video capture
    video_cap = cv2.VideoCapture(source)
    total_frames = min(int(video_cap.get(cv2.CAP_PROP_FRAME_COUNT)), max_frames)  # Limit to max_frames
    frame_width = int(video_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(video_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Prepare for frame-by-frame processing
    frame_count = 0
    total_fps = 0
    video_frames = []
    fps_values = []
    detection_counts = []

    # Loop through each frame in the video
    while video_cap.isOpened() and frame_count < max_frames:
        ret, frame = video_cap.read()
        if not ret:
            break

        start = time.time()  # Start timing

        # Perform detection based on model type
        if file_extension == ".engine":
            cls, conf, box = tensorrt_detection(model, source, frame)
        else:
            cls, conf, box = yolov8_detection(model, frame)

        # Pack detections and annotate the frame
        detection_output = list(zip(cls, conf, box))
        image_output = draw_box(frame, detection_output, label_map, COLORS)

        end = time.time()  # End timing
        fps = 1 / (end - start)  # Calculate FPS
        frame_count += 1
        total_fps += fps

        # Annotate FPS on the frame
        image_output = draw_fps(total_fps / frame_count, image_output)
        video_frames.append(image_output)  # Save annotated frame

        # Collect FPS and detection counts for graphing
        fps_values.append(fps)
        detection_counts.append(len(cls))

        print(f"Processed frame {frame_count}/{total_frames}")  # Log progress

    avg_fps = total_fps / frame_count  # Calculate average FPS
    print(f"Average FPS: {avg_fps}")

    # Save the annotated video
    file_name = get_name(source)
    save_path = get_save_path(file_name, name)
    out = cv2.VideoWriter(save_path, cv2.VideoWriter_fourcc(*'XVID'), int(avg_fps), (frame_width, frame_height))

    for frame in video_frames:
        out.write(frame)

    out.release()  # Release the writer
    print(f"Video saved at: {save_path}")

    # Plot FPS graph (Line Graph)
    plt.figure(figsize=(10, 5))
    plt.plot(fps_values, label='FPS', color='blue')
    plt.title("FPS Over Time")
    plt.xlabel("Frame Number")
    plt.ylabel("FPS")
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot number of detections graph (Line Graph)
    plt.figure(figsize=(10, 5))
    plt.plot(detection_counts, label='Detections', color='green')
    plt.title("Number of Detections Over Time")
    plt.xlabel("Frame Number")
    plt.ylabel("Number of Detections")
    plt.legend()
    plt.grid(True)
    plt.show()

# Paths for your model and video
model_path = '/content/last.pt'  # Path to your YOLO model
video_path = '/content/drive/MyDrive/video2.mp4'    # Path to your video
output_folder = "/content"  # Folder for saving output

# Run detection for first 500 frames
detection(model_path, video_path, output_folder, max_frames=400)
# Out:
# Processed frame 1/400
# Processed frame 2/400
# Processed frame 3/400
# Processed frame 4/400
# Processed frame 5/400
# Processed frame 6/400
# Processed frame 7/400
# Processed frame 8/400
# Processed frame 9/400
# Processed frame 10/400
# Processed frame 11/400
# Processed frame 12/400
# Processed frame 13/400
# Processed frame 14/400
# Processed frame 15/400
# Processed frame 16/400
# Processed frame 17/400
# Processed frame 18/400
# Processed frame 19/400
# Processed frame 20/400
# Processed frame 21/400
# Processed frame 22/400
# Processed frame 23/400
# Processed frame 24/400
# Processed frame 25/400
# Processed frame 26/400
# Processed frame 27/400
# Processed frame 28/400
# Processed frame 29/400
# Processed frame 30/400
# Processed frame 31/400
# Processed frame 32/400
# Processed frame 33/400
# Processed frame 34/400
# Processed frame 35/400
# Processed frame 36/400
# Processed frame 37/400
# Processed frame 38/400
# Processed frame 39/400
# Processed frame 40/400
# ...
